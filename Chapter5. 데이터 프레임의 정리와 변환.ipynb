# %% [markdown]
# #### 핵심내용
# - 데이터 선택 및 필터링하기
# - 열 생성 및 삭제하기
# - 결측값이 있는 열 검색 및 수정하기
# - 데이터 프레임의 인덱싱과 정렬하기
# - join과 union을 사용해 데이터 프레임 결합하기
# - 텍스트 형식과 파케이 형식으로 데이터 프레임 작성하기

# %%
# library
import dask.dataframe as dd
from dask.diagnostics import ProgressBar
import numpy as np

# %%
dtypes = {
 'Date First Observed': str,
 'Days Parking In Effect    ': str,
 'Double Parking Violation': str,
 'Feet From Curb': np.float32,
 'From Hours In Effect': str,
 'House Number': str,
 'Hydrant Violation': str,
 'Intersecting Street': str,
 'Issue Date': str,
 'Issuer Code': np.float32,
 'Issuer Command': str,
 'Issuer Precinct': np.float32,
 'Issuer Squad': str,
 'Issuing Agency': str,
 'Law Section': np.float32,
 'Meter Number': str,
 'No Standing or Stopping Violation': str,
 'Plate ID': str,
 'Plate Type': str,
 'Registration State': str,
 'Street Code1': np.uint32,
 'Street Code2': np.uint32,
 'Street Code3': np.uint32,
 'Street Name': str,
 'Sub Division': str,
 'Summons Number': np.uint32,
 'Time First Observed': str,
 'To Hours In Effect': str,
 'Unregistered Vehicle?': str,
 'Vehicle Body Type': str,
 'Vehicle Color': str,
 'Vehicle Expiration Date': str,
 'Vehicle Make': str,
 'Vehicle Year': np.float32,
 'Violation Code': np.uint16,
 'Violation County': str,
 'Violation Description': str,
 'Violation In Front Of Or Opposite': str,
 'Violation Legal Code': str,
 'Violation Location': str,
 'Violation Post Code': str,
 'Violation Precinct': np.float32,
 'Violation Time': str
}

# %%
nyc_data_raw = dd.read_csv('./data/*.csv', dtype=dtypes, usecols=dtypes.keys())

# %% [markdown]
# #### 1. 인덱스 및 축 작업하기

# %%
# 데이터 프레임에서 단일 열 선택하기
with ProgressBar() : 
    display(nyc_data_raw['Plate ID'].head())
# Out:
# [########################################] | 100% Completed |  1.9s
# 0    GBB9093
# 1    62416MB
# 2    78755JZ
# 3    63009MA
# 4    91648MC
# Name: Plate ID, dtype: object

# %%
# 데이터 프레임에서 여러 열 선택하기
with ProgressBar() :
    display(nyc_data_raw[['Plate ID', 'Registration State']].head())
# Out:
# [########################################] | 100% Completed |  1.8s
#   Plate ID Registration State
# 0  GBB9093                 NY
# 1  62416MB                 NY
# 2  78755JZ                 NY
# 3  63009MA                 NY
# 4  91648MC                 NY

# %%
# 데이터 프레임에서 열 삭제하기
with ProgressBar() :
    display(nyc_data_raw.drop('Violation Code', axis=1).head())
# Out:
# [########################################] | 100% Completed |  1.9s
#    Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0      1283294138  GBB9093                 NY        PAS  08/04/2013
# 1      1283294151  62416MB                 NY        COM  08/04/2013
# 2      1283294163  78755JZ                 NY        COM  08/05/2013
# 3      1283294175  63009MA                 NY        COM  08/05/2013
# 4      1283294187  91648MC                 NY        COM  08/08/2013
#
#   Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  Street Code2  \
# 0              SUBN         AUDI              P         37250         13610
# 1               VAN         FORD              P         37290         40404
# 2               P-U        CHEVR              P         37030         31190
# 3               VAN         FORD              P         37270         11710
# 4              TRLR          GMC              P         37240         12010
#
#    ...  Vehicle Color Unregistered Vehicle? Vehicle Year  Meter Number  \
# 0  ...             GY                     0       2013.0             -
# 1  ...             WH                     0       2012.0             -
# 2  ...            NaN                     0          0.0             -
# 3  ...             WH                     0       2010.0             -
# 4  ...             BR                     0       2012.0             -
#
#    Feet From Curb  Violation Post Code Violation Description  \
# 0             0.0                  NaN                   NaN
# 1             0.0                  NaN                   NaN
# 2             0.0                  NaN                   NaN
# 3             0.0                  NaN                   NaN
# 4             0.0                  NaN                   NaN
#
#   No Standing or Stopping Violation Hydrant Violation Double Parking Violation
# 0                               NaN               NaN                      NaN
# 1                               NaN               NaN                      NaN
# 2                               NaN               NaN                      NaN
# 3                               NaN               NaN                      NaN
# 4                               NaN               NaN                      NaN
#
# [5 rows x 42 columns]

# %%
# 데이터 프레임에서 여러 열 삭제하기
violationColumnNames = list(filter(
    lambda columnName : 'Violation' in columnName, nyc_data_raw.columns)
                           )
with ProgressBar() : 
    display(nyc_data_raw.drop(violationColumnNames, axis=1).head())
# Out:
# [########################################] | 100% Completed |  1.9s
#    Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0      1283294138  GBB9093                 NY        PAS  08/04/2013
# 1      1283294151  62416MB                 NY        COM  08/04/2013
# 2      1283294163  78755JZ                 NY        COM  08/05/2013
# 3      1283294175  63009MA                 NY        COM  08/05/2013
# 4      1283294187  91648MC                 NY        COM  08/08/2013
#
#   Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  Street Code2  \
# 0              SUBN         AUDI              P         37250         13610
# 1               VAN         FORD              P         37290         40404
# 2               P-U        CHEVR              P         37030         31190
# 3               VAN         FORD              P         37270         11710
# 4              TRLR          GMC              P         37240         12010
#
#    ...  Law Section Sub Division  Days Parking In Effect      \
# 0  ...        408.0           F1                     BBBBBBB
# 1  ...        408.0            C                     BBBBBBB
# 2  ...        408.0           F7                     BBBBBBB
# 3  ...        408.0           F1                     BBBBBBB
# 4  ...        408.0           E1                     BBBBBBB
#
#    From Hours In Effect To Hours In Effect Vehicle Color  \
# 0                   ALL                ALL            GY
# 1                   ALL                ALL            WH
# 2                   ALL                ALL           NaN
# 3                   ALL                ALL            WH
# 4                   ALL                ALL            BR
#
#   Unregistered Vehicle? Vehicle Year Meter Number Feet From Curb
# 0                     0       2013.0            -            0.0
# 1                     0       2012.0            -            0.0
# 2                     0          0.0            -            0.0
# 3                     0       2010.0            -            0.0
# 4                     0       2012.0            -            0.0
#
# [5 rows x 31 columns]

# %%
# 열이름 바꾸기
nyc_data_renamed = nyc_data_raw.rename(columns={'Plate ID' : 'License Plate'})
nyc_data_renamed
# Out:
# Dask DataFrame Structure:
#                 Summons Number License Plate Registration State Plate Type Issue Date Violation Code Vehicle Body Type Vehicle Make Issuing Agency Street Code1 Street Code2 Street Code3 Vehicle Expiration Date Violation Location Violation Precinct Issuer Precinct Issuer Code Issuer Command Issuer Squad Violation Time Time First Observed Violation County Violation In Front Of Or Opposite House Number Street Name Intersecting Street Date First Observed Law Section Sub Division Violation Legal Code Days Parking In Effect     From Hours In Effect To Hours In Effect Vehicle Color Unregistered Vehicle? Vehicle Year Meter Number Feet From Curb Violation Post Code Violation Description No Standing or Stopping Violation Hydrant Violation Double Parking Violation
# npartitions=138
#                         uint32        object             object     object     object         uint16            object       object         object       uint32       uint32       uint32                  object             object            float32         float32     float32         object       object         object              object           object                            object       object      object              object              object     float32       object               object                     object               object             object        object                object      float32       object        float32              object                object                            object            object                   object
#                            ...           ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
# ...                        ...           ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
#                            ...           ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
#                            ...           ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
# Dask Name: rename, 276 tasks

# %%
# 단일 행 선택하기
with ProgressBar() : 
    display(nyc_data_raw.loc[56].head(1))
# Out:
# [########################################] | 100% Completed |  1.7s
#     Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 56      1293090530  GES3519                 NY        PAS  07/07/2013
#
#     Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 56              40               SDN        HONDA              F
#
#     Street Code1  ...  Vehicle Color  Unregistered Vehicle? Vehicle Year  \
# 56         70630  ...          BLACK                      0       1997.0
#
#    Meter Number  Feet From Curb  Violation Post Code  Violation Description  \
# 56            -             0.0                  NaN                    NaN
#
#    No Standing or Stopping Violation Hydrant Violation  \
# 56                               NaN               NaN
#
#    Double Parking Violation
# 56                      NaN
#
# [1 rows x 43 columns]

# %%
# 인덱스로 행을 순차적으로 가져오기
with ProgressBar() :
    display(nyc_data_raw.loc[100:200].head(100))
# Out:
# [########################################] | 100% Completed |  1.7s
#      Summons Number  Plate ID Registration State Plate Type  Issue Date  \
# 100      1294727205   XBD7628                 VA        PAS  08/04/2013
# 101      1294727461   R613159                 IL        PAS  07/17/2013
# 102      1294727473   6TCX735                 CA        PAS  07/18/2013
# 103      1294727497    ZWZ43K                 NJ        PAS  08/10/2013
# 104      1295357240  T624858C                 NY        PAS  07/22/2013
# ..              ...       ...                ...        ...         ...
# 195      1307953700    481CKW                 NJ        PAS  07/27/2013
# 196      1307953724    W122KP                 NY        PAS  07/28/2013
# 197      1307953761   GAW6458                 NY        PAS  08/17/2013
# 198      1307953852   GFP6251                 NY        PAS  08/24/2013
# 199      1307953876   JGV1886                 PA        PAS  08/11/2013
#
#      Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 100              17              SUBN         JEEP              P
# 101              17               SDN        VOLKS              P
# 102              17               SDN        MAZDA              P
# 103              17              SUBN        LINCO              P
# 104              21              SUBN        TOYOT              X
# ..              ...               ...          ...            ...
# 195              24              SUBN        NISSA              K
# 196              20               SDN        TOYOT              K
# 197              20               SDN        TOYOT              K
# 198              27               SDN        NISSA              K
# 199              20              SUBN         FORD              K
#
#      Street Code1  ...  Vehicle Color  Unregistered Vehicle? Vehicle Year  \
# 100         14510  ...            GRY                      0          0.0
# 101         14510  ...           BLUE                      0          0.0
# 102         14510  ...          BLACK                      0          0.0
# 103         14510  ...            NaN                      0          0.0
# 104         28790  ...          SILVE                      0       2012.0
# ..            ...  ...            ...                    ...          ...
# 195             0  ...          PURPL                      0          0.0
# 196             0  ...          MAROO                      0       1998.0
# 197         48502  ...          BLACK                      0       2001.0
# 198             0  ...            G/Y                      0       2006.0
# 199         11220  ...             GY                      0          0.0
#
#     Meter Number  Feet From Curb  Violation Post Code  Violation Description  \
# 100            -             0.0                  NaN                    NaN
# 101            -             0.0                  NaN                    NaN
# 102            -             0.0                  NaN                    NaN
# 103            -             0.0                  NaN                    NaN
# 104            -             0.0                  NaN                    NaN
# ..           ...             ...                  ...                    ...
# 195            -             0.0                  NaN                    NaN
# 196            -             0.0                  NaN                    NaN
# 197            -             0.0                  NaN                    NaN
# 198            -             0.0                  NaN                    NaN
# 199            -             0.0                  NaN                    NaN
#
#     No Standing or Stopping Violation Hydrant Violation  \
# 100                               NaN               NaN
# 101                               NaN               NaN
# 102                               NaN               NaN
# 103                               NaN               NaN
# 104                               NaN               NaN
# ..                                ...               ...
# 195                               NaN               NaN
# 196                               NaN               NaN
# 197                               NaN               NaN
# 198                               NaN               NaN
# 199                               NaN               NaN
#
#     Double Parking Violation
# 100                      NaN
# 101                      NaN
# 102                      NaN
# 103                      NaN
# 104                      NaN
# ..                       ...
# 195                      NaN
# 196                      NaN
# 197                      NaN
# 198                      NaN
# 199                      NaN
#
# [100 rows x 43 columns]

# %%
# 대스크와 팬더스를 사용해 행 슬라이스 필터링하기
with ProgressBar() :
    some_rows = nyc_data_raw.loc[100:200].head(100)
    
some_rows.drop(range(100, 200, 2))
# Out:
# [########################################] | 100% Completed |  1.7s
#      Summons Number  Plate ID Registration State Plate Type  Issue Date  \
# 101      1294727461   R613159                 IL        PAS  07/17/2013
# 103      1294727497    ZWZ43K                 NJ        PAS  08/10/2013
# 105      1295546486   42909JM                 NY        COM  07/17/2013
# 107      1302446484    452WW4                 MA        PAS  06/24/2013
# 109      1302453774   GEX5296                 NY        PAS  07/26/2013
# 111      1302453798    867ZFX                 CT        PAS  07/15/2013
# 113      1302456593   GEZ1408                 NY        PAS  07/15/2013
# 115      1302456738    UCSLIM                 NY        PAS  08/07/2013
# 117      1302466203   HPM2636                 PA        PAS  08/08/2013
# 119      1302466227  TWODAMAX                 NY        SRF  08/05/2013
# 121      1302466318    K39845                 NY        PAS  07/26/2013
# 123      1302466331   GJA3150                 NY        OMS  07/12/2013
# 125      1302466380   GGS5125                 NY        PAS  07/09/2013
# 127      1302466483   GEF7281                 NY        PAS  06/28/2013
# 129      1302494843   GHM9264                 NY        PAS  07/20/2013
# 131      1302494867    W36CKK                 NJ        PAS  07/20/2013
# 133      1302494934   GJA3298                 NY        OMS  07/19/2013
# 135      1302494983     RPH78                 NY        SRF  07/19/2013
# 137      1302501653   GDE3096                 NY        PAS  07/24/2013
# 139      1302511257   GFP5637                 NY        PAS  07/18/2013
# 141      1302513254   GEF7457                 NY        PAS  07/21/2013
# 143      1302870749   96272JY                 NY        COM  08/02/2013
# 145      1305400720   STN2382                 NC        PAS  08/03/2013
# 147      1306114172   91628MC                 NY        COM  08/02/2013
# 149      1306114196   62092JL                 NY        COM  08/23/2013
# 151      1306206844   55197JJ                 NY        COM  08/06/2013
# 153      1306632572   45940MD                 NY        COM  08/01/2013
# 155      1306755700    Y309CZ                 NY        PAS  08/02/2013
# 157      1306757629    561CVB                 NJ        PAS  08/06/2013
# 159      1306757861    5CA14E                 MI        PAS  08/02/2013
# 161      1306759249   GEK4279                 NY        PAS  08/02/2013
# 163      1306759262   GDL7143                 NY        PAS  08/16/2013
# 165      1306759432   JLE4572                 PA        PAS  07/23/2013
# 167      1306759481   HSW7971                 PA        PAS  07/24/2013
# 169      1306771572   WUV6389                 VA        PAS  08/19/2013
# 171      1306771596   GFF5181                 NY        PAS  08/19/2013
# 173      1306775462    P47914                 MA        COM  07/29/2013
# 175      1307045133   GFC8953                 NY        PAS  07/26/2013
# 177      1307238828   GEX4415                 NY        PAS  08/18/2013
# 179      1307452577   55003JG                 NY        COM  08/12/2013
# 181      1307452590   40470JU                 99        COM  08/12/2013
# 183      1307846646      7L6A                 NY        SRF  08/14/2013
# 185      1307935217    H50DHM                 NJ        PAS  07/30/2013
# 187      1307952574    UDV99Y                 NJ        PAS  07/21/2013
# 189      1307952987   GGW8417                 NY        PAS  07/21/2013
# 191      1307953128    N34ASW                 NJ        PAS  08/11/2013
# 193      1307953682   GGS6051                 NY        PAS  07/27/2013
# 195      1307953700    481CKW                 NJ        PAS  07/27/2013
# 197      1307953761   GAW6458                 NY        PAS  08/17/2013
# 199      1307953876   JGV1886                 PA        PAS  08/11/2013
#
#      Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 101              17               SDN        VOLKS              P
# 103              17              SUBN        LINCO              P
# 105              19              DELV        MERCU              P
# 107              46               SDN        CHEVR              C
# 109              14               SDN        ME/BE              C
# 111              17               SDN        ACURA              C
# 113              17              SUBN        HYUND              X
# 115              17              SUBN         FORD              X
# 117              40              SUBN        CADIL              X
# 119              17               SDN        HYUND              X
# 121              17               SDN        TOYOT              X
# 123              40               SDN        CHEVR              X
# 125              17               SDN        VOLVO              X
# 127              17               NaN        HYUND              X
# 129              63              SUBN        ROVER              X
# 131              63               SDN        NISSA              X
# 133              63               SDN        NISSA              X
# 135              63               SDN        TOYOT              X
# 137              24              FOUR        ME/BE              X
# 139              20              SUBN        TOYOT              X
# 141              20               SDN        PONTI              X
# 143              14              DELV        MITSU              T
# 145              40              SUBN        NISSA              P
# 147              46              REFG         HINO              P
# 149              46              REFG        ISUZU              P
# 151              46              DELV          NaN              P
# 153              78               VAN         FORD              P
# 155              21              SUBN          NaN              S
# 157              21              SUBN          BMW              S
# 159              21               SDN        HONDA              S
# 161              21               SDN          BMW              S
# 163              21               SDN          BMW              S
# 165              21               SDN        NISSA              S
# 167              21              SUBN        MAZDA              S
# 169              21              SUBN          GMC              S
# 171              21              SUBN        CHEVR              S
# 173              40               VAN         FORD              S
# 175              20               SDN        HONDA              P
# 177              14               SDN        HONDA              P
# 179              46              DELV        WORKV              P
# 181              46              DELV        MERCU              P
# 183              14              TAXI        TOYOT              P
# 185              40               SDN        MITSU              K
# 187              20               SDN        CHEVR              K
# 189              63              SUBN         JEEP              K
# 191              61               SDN        CHEVR              K
# 193              24               SDN        NISSA              K
# 195              24              SUBN        NISSA              K
# 197              20               SDN        TOYOT              K
# 199              20              SUBN         FORD              K
#
#      Street Code1  ...  Vehicle Color  Unregistered Vehicle? Vehicle Year  \
# 101         14510  ...           BLUE                      0          0.0
# 103         14510  ...            NaN                      0          0.0
# 105         58590  ...          BROWN                      0       1996.0
# 107         75530  ...          YELLO                      0       2013.0
# 109         36420  ...          BLACK                      0          0.0
# 111             0  ...          WHITE                      0          0.0
# 113         77730  ...            BLK                      0       2013.0
# 115         77730  ...            BLK                      0       2003.0
# 117         24245  ...          SILVR                      0          0.0
# 119         53630  ...           GRAY                      0       2012.0
# 121         11700  ...           BLUE                      0          0.0
# 123         53630  ...          SILVR                      0       2013.0
# 125         53630  ...          WHITE                      0       2004.0
# 127         11800  ...           BIRG                      0       2006.0
# 129             0  ...             GY                      0       2008.0
# 131             0  ...             BK                      0          0.0
# 133             0  ...             GY                      0       2013.0
# 135             0  ...          BEIGE                      0       2005.0
# 137             0  ...          WHITE                      0       1990.0
# 139             0  ...           GRAY                      0       2012.0
# 141             0  ...          WHITE                      0       1995.0
# 143         18250  ...             WH                      0       2005.0
# 145             0  ...           GRAY                      0       2004.0
# 147         36490  ...             WH                      0       2007.0
# 149             0  ...             OR                      0       2011.0
# 151         13110  ...              W                      0       2001.0
# 153         44240  ...            WHT                      0       2013.0
# 155         52490  ...           GRAY                      0       2013.0
# 157         45990  ...            SIL                      0          0.0
# 159         53190  ...          GREEN                      0          0.0
# 161         23180  ...          BLACK                      0       2002.0
# 163         23180  ...            WHT                      0       2013.0
# 165         24540  ...            BLK                      0          0.0
# 167         24040  ...            BLK                      0       2012.0
# 169         12330  ...          WHITE                      0          0.0
# 171         12330  ...           BLUE                      0       2004.0
# 173         29890  ...            TAN                      0          0.0
# 175         61030  ...             BK                      0       1997.0
# 177         65120  ...            BLK                      0       2004.0
# 179         10010  ...          WHITE                      0       1999.0
# 181         10110  ...          WHITE                      0       2004.0
# 183         36210  ...          YELLO                      0       2010.0
# 185         45210  ...          GREEN                      0          0.0
# 187             0  ...           BLUE                      0          0.0
# 189             0  ...          BLACK                      0       2003.0
# 191             0  ...             BL                      0          0.0
# 193             0  ...           BLUE                      0       2008.0
# 195             0  ...          PURPL                      0          0.0
# 197         48502  ...          BLACK                      0       2001.0
# 199         11220  ...             GY                      0          0.0
#
#     Meter Number  Feet From Curb  Violation Post Code  Violation Description  \
# 101            -             0.0                  NaN                    NaN
# 103            -             0.0                  NaN                    NaN
# 105            -             0.0                  NaN                    NaN
# 107            -             0.0                  NaN                    NaN
# 109            -             0.0                  NaN                    NaN
# 111            -             0.0                  NaN                    NaN
# 113            -             0.0                  NaN                    NaN
# 115            -             0.0                  NaN                    NaN
# 117            -             0.0                  NaN                    NaN
# 119            -             0.0                  NaN                    NaN
# 121            -             0.0                  NaN                    NaN
# 123            -             0.0                  NaN                    NaN
# 125            -             0.0                  NaN                    NaN
# 127            -             0.0                  NaN                    NaN
# 129            -             0.0                  NaN                    NaN
# 131            -             0.0                  NaN                    NaN
# 133            -             0.0                  NaN                    NaN
# 135            -             0.0                  NaN                    NaN
# 137            -             0.0                  NaN                    NaN
# 139            -             0.0                  NaN                    NaN
# 141            -             0.0                  NaN                    NaN
# 143            -             0.0                  NaN                    NaN
# 145            -             0.0                  NaN                    NaN
# 147            -             0.0                  NaN                    NaN
# 149            -             0.0                  NaN                    NaN
# 151            -             0.0                  NaN                    NaN
# 153            -             0.0                  NaN                    NaN
# 155            -             0.0                  NaN                    NaN
# 157            -             0.0                  NaN                    NaN
# 159            -             0.0                  NaN                    NaN
# 161            -             0.0                  NaN                    NaN
# 163            -             0.0                  NaN                    NaN
# 165            -             0.0                  NaN                    NaN
# 167            -             0.0                  NaN                    NaN
# 169            -             0.0                  NaN                    NaN
# 171            -             0.0                  NaN                    NaN
# 173            -             0.0                  NaN                    NaN
# 175            -             0.0                  NaN                    NaN
# 177            -             0.0                  NaN                    NaN
# 179            -             0.0                  NaN                    NaN
# 181            -             0.0                  NaN                    NaN
# 183            -             0.0                  NaN                    NaN
# 185            -             5.0                  NaN                    NaN
# 187            -             0.0                  NaN                    NaN
# 189            -             0.0                  NaN                    NaN
# 191            -             0.0                  NaN                    NaN
# 193            -             0.0                  NaN                    NaN
# 195            -             0.0                  NaN                    NaN
# 197            -             0.0                  NaN                    NaN
# 199            -             0.0                  NaN                    NaN
#
#     No Standing or Stopping Violation Hydrant Violation  \
# 101                               NaN               NaN
# 103                               NaN               NaN
# 105                               NaN               NaN
# 107                               NaN               NaN
# 109                               NaN               NaN
# 111                               NaN               NaN
# 113                               NaN               NaN
# 115                               NaN               NaN
# 117                               NaN               NaN
# 119                               NaN               NaN
# 121                               NaN               NaN
# 123                               NaN               NaN
# 125                               NaN               NaN
# 127                               NaN               NaN
# 129                               NaN               NaN
# 131                               NaN               NaN
# 133                               NaN               NaN
# 135                               NaN               NaN
# 137                               NaN               NaN
# 139                               NaN               NaN
# 141                               NaN               NaN
# 143                               NaN               NaN
# 145                               NaN               NaN
# 147                               NaN               NaN
# 149                               NaN               NaN
# 151                               NaN               NaN
# 153                               NaN               NaN
# 155                               NaN               NaN
# 157                               NaN               NaN
# 159                               NaN               NaN
# 161                               NaN               NaN
# 163                               NaN               NaN
# 165                               NaN               NaN
# 167                               NaN               NaN
# 169                               NaN               NaN
# 171                               NaN               NaN
# 173                               NaN               NaN
# 175                               NaN               NaN
# 177                               NaN               NaN
# 179                               NaN               NaN
# 181                               NaN               NaN
# 183                               NaN               NaN
# 185                               NaN               NaN
# 187                               NaN               NaN
# 189                               NaN               NaN
# 191                               NaN               NaN
# 193                               NaN               NaN
# 195                               NaN               NaN
# 197                               NaN               NaN
# 199                               NaN               NaN
#
#     Double Parking Violation
# 101                      NaN
# 103                      NaN
# 105                      NaN
# 107                      NaN
# 109                      NaN
# 111                      NaN
# 113                      NaN
# 115                      NaN
# 117                      NaN
# 119                      NaN
# 121                      NaN
# 123                      NaN
# 125                      NaN
# 127                      NaN
# 129                      NaN
# 131                      NaN
# 133                      NaN
# 135                      NaN
# 137                      NaN
# 139                      NaN
# 141                      NaN
# 143                      NaN
# 145                      NaN
# 147                      NaN
# 149                      NaN
# 151                      NaN
# 153                      NaN
# 155                      NaN
# 157                      NaN
# 159                      NaN
# 161                      NaN
# 163                      NaN
# 165                      NaN
# 167                      NaN
# 169                      NaN
# 171                      NaN
# 173                      NaN
# 175                      NaN
# 177                      NaN
# 179                      NaN
# 181                      NaN
# 183                      NaN
# 185                      NaN
# 187                      NaN
# 189                      NaN
# 191                      NaN
# 193                      NaN
# 195                      NaN
# 197                      NaN
# 199                      NaN
#
# [50 rows x 43 columns]

# %% [markdown]
# #### 2. 결측값 다루기

# %%
# 열별로 결측값 백분율 계산하기
missing_values = nyc_data_raw.isnull().sum()

with ProgressBar() : 
    percent_missing = ((missing_values / nyc_data_raw.index.size) * 100).compute()

percent_missing
# Out:
# [########################################] | 100% Completed |  6min  9.5s
# Summons Number                        0.000000
# Plate ID                              0.020867
# Registration State                    0.000000
# Plate Type                            0.000000
# Issue Date                            0.000000
# Violation Code                        0.000000
# Vehicle Body Type                     0.564922
# Vehicle Make                          0.650526
# Issuing Agency                        0.000000
# Street Code1                          0.000000
# Street Code2                          0.000000
# Street Code3                          0.000000
# Vehicle Expiration Date               0.000002
# Violation Location                   15.142846
# Violation Precinct                    0.000002
# Issuer Precinct                       0.000002
# Issuer Code                           0.000002
# Issuer Command                       15.018851
# Issuer Squad                         15.022566
# Violation Time                        0.019207
# Time First Observed                  90.040886
# Violation County                     10.154892
# Violation In Front Of Or Opposite    15.953282
# House Number                         16.932473
# Street Name                           0.054894
# Intersecting Street                  72.571941
# Date First Observed                   0.000007
# Law Section                           0.000007
# Sub Division                          0.012412
# Violation Legal Code                 84.970398
# Days Parking In Effect               23.225424
# From Hours In Effect                 44.821011
# To Hours In Effect                   44.821004
# Vehicle Color                         1.152299
# Unregistered Vehicle?                88.484122
# Vehicle Year                          0.000012
# Meter Number                         81.115883
# Feet From Curb                        0.000012
# Violation Post Code                  26.532350
# Violation Description                11.523098
# No Standing or Stopping Violation    99.999998
# Hydrant Violation                    99.999998
# Double Parking Violation             99.999998
# dtype: float64

# %%
# 결측값이 50% 이상인 열 삭제
columns_to_drop = list(percent_missing[percent_missing >= 50].index)
nyc_data_clean_stage1 = nyc_data_raw.drop(columns_to_drop, axis=1)

# %%
# 결측값 대체하기
# 가정 : 누락된 값이 데이터셋에서 가장 일반적인 색상일 것.
with ProgressBar() :
    count_of_vehicle_colors = nyc_data_clean_stage1['Vehicle Color'].value_counts().compute()

most_common_color = count_of_vehicle_colors.sort_values(ascending=False).index[0]

nyc_data_clean_stage2 = nyc_data_clean_stage1.fillna({'Vehicle Color' : most_common_color})
# Out:
# [########################################] | 100% Completed |  3min 32.5s

# %%
with ProgressBar() :
    print(len(nyc_data_raw))
# Out:
# [########################################] | 100% Completed |  3min 17.2s
# 42339438

# %%
count_of_vehicle_colors
# Out:
# GY       6280314
# WH       6074770
# WHITE    5624960
# BK       5121030
# BLACK    2758479
#           ...
# I.MG           1
# I.MJE          1
# I.NC           1
# I.Y.A          1
# white          1
# Name: Vehicle Color, Length: 5744, dtype: int64

# %%
# 결측값이 있는 열 삭제하기
rows_to_drop = list(percent_missing[(percent_missing > 0) & (percent_missing < 5)].index)
nyc_data_clean_stage3 = nyc_data_clean_stage2.dropna(subset=rows_to_drop)

# %%
rows_to_drop
# Out:
# ['Plate ID',
#  'Vehicle Body Type',
#  'Vehicle Make',
#  'Vehicle Expiration Date',
#  'Violation Precinct',
#  'Issuer Precinct',
#  'Issuer Code',
#  'Violation Time',
#  'Street Name',
#  'Date First Observed',
#  'Law Section',
#  'Sub Division',
#  'Vehicle Color',
#  'Vehicle Year',
#  'Feet From Curb']

# %%
# 남은 열들의 데이터 타입 찾기
remaining_columns_to_clean = list(
    percent_missing[(percent_missing >=5) & percent_missing <50].index
)
nyc_data_raw.dtypes[remaining_columns_to_clean]
# Out:
# Summons Number                        uint32
# Plate ID                              object
# Registration State                    object
# Plate Type                            object
# Issue Date                            object
# Violation Code                        uint16
# Vehicle Body Type                     object
# Vehicle Make                          object
# Issuing Agency                        object
# Street Code1                          uint32
# Street Code2                          uint32
# Street Code3                          uint32
# Vehicle Expiration Date               object
# Violation Location                    object
# Violation Precinct                   float32
# Issuer Precinct                      float32
# Issuer Code                          float32
# Issuer Command                        object
# Issuer Squad                          object
# Violation Time                        object
# Time First Observed                   object
# Violation County                      object
# Violation In Front Of Or Opposite     object
# House Number                          object
# Street Name                           object
# Intersecting Street                   object
# Date First Observed                   object
# Law Section                          float32
# Sub Division                          object
# Violation Legal Code                  object
# Days Parking In Effect                object
# From Hours In Effect                  object
# To Hours In Effect                    object
# Vehicle Color                         object
# Unregistered Vehicle?                 object
# Vehicle Year                         float32
# Meter Number                          object
# Feet From Curb                       float32
# Violation Post Code                   object
# Violation Description                 object
# No Standing or Stopping Violation     object
# Hydrant Violation                     object
# Double Parking Violation              object
# dtype: object

# %%
# fillna를 위한 대체값 딕셔너리 만들기
unknown_default_dict = dict(map(
    lambda columnName: (columnName, 'Unknown'), remaining_columns_to_clean
    )
)

# %%
# 기본값으로 데이터 프레임 채우기
nyc_data_clean_stage4 = nyc_data_clean_stage3.fillna(unknown_default_dict)

# %%
nyc_data_clean_stage4
# Out:
# Dask DataFrame Structure:
#                 Summons Number Plate ID Registration State Plate Type Issue Date Violation Code Vehicle Body Type Vehicle Make Issuing Agency Street Code1 Street Code2 Street Code3 Vehicle Expiration Date Violation Location Violation Precinct Issuer Precinct Issuer Code Issuer Command Issuer Squad Violation Time Violation County Violation In Front Of Or Opposite House Number Street Name Date First Observed Law Section Sub Division Days Parking In Effect     From Hours In Effect To Hours In Effect Vehicle Color Vehicle Year Feet From Curb Violation Post Code Violation Description
# npartitions=138
#                         uint32   object             object     object     object         uint16            object       object         object       uint32       uint32       uint32                  object             object            float32         float32     float32         object       object         object           object                            object       object      object              object     float32       object                     object               object             object        object      float32        float32              object                object
#                            ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...              ...                               ...          ...         ...                 ...         ...          ...                        ...                  ...                ...           ...          ...            ...                 ...                   ...
# ...                        ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...              ...                               ...          ...         ...                 ...         ...          ...                        ...                  ...                ...           ...          ...            ...                 ...                   ...
#                            ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...              ...                               ...          ...         ...                 ...         ...          ...                        ...                  ...                ...           ...          ...            ...                 ...                   ...
#                            ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...              ...                               ...          ...         ...                 ...         ...          ...                        ...                  ...                ...           ...          ...            ...                 ...                   ...
# Dask Name: fillna, 691 tasks

# %%
# 채우기/삭제 작업이 잘 됐는지 확인하기
with ProgressBar() :
    print(nyc_data_clean_stage4.isnull().sum().compute())

nyc_data_clean_stage4.persist()
# Out:
# [########################################] | 100% Completed |  9min 48.4s
# Summons Number                       0
# Plate ID                             0
# Registration State                   0
# Plate Type                           0
# Issue Date                           0
# Violation Code                       0
# Vehicle Body Type                    0
# Vehicle Make                         0
# Issuing Agency                       0
# Street Code1                         0
# Street Code2                         0
# Street Code3                         0
# Vehicle Expiration Date              0
# Violation Location                   0
# Violation Precinct                   0
# Issuer Precinct                      0
# Issuer Code                          0
# Issuer Command                       0
# Issuer Squad                         0
# Violation Time                       0
# Violation County                     0
# Violation In Front Of Or Opposite    0
# House Number                         0
# Street Name                          0
# Date First Observed                  0
# Law Section                          0
# Sub Division                         0
# Days Parking In Effect               0
# From Hours In Effect                 0
# To Hours In Effect                   0
# Vehicle Color                        0
# Vehicle Year                         0
# Feet From Curb                       0
# Violation Post Code                  0
# Violation Description                0
# dtype: int64
# Dask DataFrame Structure:
#                 Summons Number Plate ID Registration State Plate Type Issue Date Violation Code Vehicle Body Type Vehicle Make Issuing Agency Street Code1 Street Code2 Street Code3 Vehicle Expiration Date Violation Location Violation Precinct Issuer Precinct Issuer Code Issuer Command Issuer Squad Violation Time Violation County Violation In Front Of Or Opposite House Number Street Name Date First Observed Law Section Sub Division Days Parking In Effect     From Hours In Effect To Hours In Effect Vehicle Color Vehicle Year Feet From Curb Violation Post Code Violation Description
# npartitions=138
#                         uint32   object             object     object     object         uint16            object       object         object       uint32       uint32       uint32                  object             object            float32         float32     float32         object       object         object           object                            object       object      object              object     float32       object                     object               object             object        object      float32        float32              object                object
#                            ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...              ...                               ...          ...         ...                 ...         ...          ...                        ...                  ...                ...           ...          ...            ...                 ...                   ...
# ...                        ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...              ...                               ...          ...         ...                 ...         ...          ...                        ...                  ...                ...           ...          ...            ...                 ...                   ...
#                            ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...              ...                               ...          ...         ...                 ...         ...          ...                        ...                  ...                ...           ...          ...            ...                 ...                   ...
#                            ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...              ...                               ...          ...         ...                 ...         ...          ...                        ...                  ...                ...           ...          ...            ...                 ...                   ...
# Dask Name: fillna, 138 tasks

# %% [markdown]
# #### 3. 데이터 기록하기

# %%
# Plate Type 열의 값 횟수 구하기
with ProgressBar() :
    license_plate_types = nyc_data_clean_stage4['Plate Type'].value_counts().compute()

license_plate_types
# Out:
# [########################################] | 100% Completed |  8min  6.5s
# PAS    30452502
# COM     7966914
# OMT     1389341
# SRF      394656
# OMS      368952
#          ...
# HOU           4
# JWV           3
# LOC           3
# HIF           2
# SNO           2
# Name: Plate Type, Length: 90, dtype: int64

# %%
# Plate Type 열 기록하기
condition = nyc_data_clean_stage4['Plate Type'].isin(['PAS', 'COM'])
plate_type_masked = nyc_data_clean_stage4['Plate Type'].where(condition, 'Other')
nyc_data_recode_stage1 = nyc_data_clean_stage4.drop('Plate Type', axis=1)
nyc_data_recode_stage2 = nyc_data_recode_stage1.assign(PlateType=plate_type_masked)
nyc_data_recode_stage3 = nyc_data_recode_stage2.rename(columns={'PlateType':'Plate Type'})

# %%
# 리코딩 후 값 횟수 보기
with ProgressBar() :
    display(nyc_data_recode_stage3['Plate Type'].value_counts().compute())
# Out:
# [########################################] | 100% Completed |  8min 46.4s
# PAS      30452502
# COM       7966914
# Other     3418586
# Name: Plate Type, dtype: int64

# %% [markdown]
# - where : 전달된 조건이 False일 때, 값을 대체
#   - 많은 고유값들 중 조금만 유지하려는 경우
# - mask : 전달된 조건이 True일 때, 값을 대체
#   - 고유값들 중 몇 개만 삭제하고자 하는 경우

# %%
# mask를 사용해 'Other' 범주에 고유한 색상 배치하기
single_color = list(count_of_vehicle_colors[count_of_vehicle_colors == 1].index)
condition = nyc_data_clean_stage4['Vehicle Color'].isin(single_color)
vehicle_color_masked = nyc_data_clean_stage4['Vehicle Color'].mask(condition, 'Other')
nyc_data_recode_stage4 = nyc_data_recode_stage3.drop('Vehicle Color', axis=1)
nyc_data_recode_stage5 = nyc_data_recode_stage4.assign(VehicleColor=vehicle_color_masked)
nyc_data_recode_stage6 = nyc_data_recode_stage5.rename(columns={'VehicleColor':'Vehicle Color'})

# %% [markdown]
# #### 3. 요소별 연산

# %%
# 발행 날짜 열 분석하기
from datetime import datetime

issue_date_parsed = nyc_data_recode_stage6['Issue Date'].apply(
    lambda x : datetime.strptime(x, '%m/%d/%Y'), meta=datetime 
    # meta=datetime : Dask의 경우 타입을 명시적으로 지정해주는게 좋다.
)
nyc_data_derived_stage1 = nyc_data_recode_stage6.drop('Issue Date', axis=1)
nyc_data_derived_stage2 = nyc_data_derived_stage1.assign(IssueDate=issue_date_parsed)
nyc_data_derived_stage3 = nyc_data_derived_stage2.rename(columns={'IssueDate':'Issue Date'})
# Out:
# /Users/cbm/workspace/dask/venv/lib/python3.9/site-packages/dask/dataframe/core.py:6240: FutureWarning: Meta is not valid, `map_partitions` expects output to be a pandas object. Try passing a pandas object as meta or a dict or tuple representing the (name, dtype) of the columns. In the future the meta you passed will not work.
#   warnings.warn(

# %%
# 날짜 파싱 결과 조사하기
with ProgressBar() :
    display(nyc_data_derived_stage3['Issue Date'].head())
# Out:
# [########################################] | 100% Completed |  6.8s
# 0   2013-08-04
# 1   2013-08-04
# 2   2013-08-05
# 3   2013-08-05
# 4   2013-08-08
# Name: Issue Date, dtype: datetime64[ns]

# %%
# 월과 연도 추출하기
issue_date_month_year = nyc_data_derived_stage3['Issue Date'].apply(
    lambda dt : dt.strftime('%Y%m'), meta=int
)
nyc_data_derived_stage4 = nyc_data_derived_stage3.assign(IssueMonthYear=issue_date_month_year)
nyc_data_derived_stage5 = nyc_data_derived_stage4.rename(
    columns={'IssueMonthYear':'Citation Issued Month Year'}
)
# Out:
# /Users/cbm/workspace/dask/venv/lib/python3.9/site-packages/dask/dataframe/core.py:6240: FutureWarning: Meta is not valid, `map_partitions` expects output to be a pandas object. Try passing a pandas object as meta or a dict or tuple representing the (name, dtype) of the columns. In the future the meta you passed will not work.
#   warnings.warn(

# %%
# 새로운 파생 열 조사하기
with ProgressBar() :
    display(nyc_data_derived_stage5['Citation Issued Month Year'].head())
# Out:
# [########################################] | 100% Completed |  8.7s
# 0    201308
# 1    201308
# 2    201308
# 3    201308
# 4    201308
# Name: Citation Issued Month Year, dtype: object

# %% [markdown]
# #### 4. 데이터 프레임의 필터링과 재색인

# %%
# 10월에 발생한 모든 주차 위반 찾기
months = ['201310', '201410', '201510', '201610', '201710']
condition = nyc_data_derived_stage5['Citation Issued Month Year'].isin(months)
october_citations = nyc_data_derived_stage5[condition]

with ProgressBar() :
    display(october_citations.head())
# Out:
# [########################################] | 100% Completed |  8.7s
#        Summons Number  Plate ID Registration State  Violation Code  \
# 1609       1340313923   GEK8055                 NY              40
# 23367      1351679867  XE726658                 DE              20
# 24172      1351805253   42067JM                 NY              14
# 32902      1355051060   76254JY                 NY              46
# 32903      1355051071   44125MC                 NY              46
#
#       Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 1609               SUBN        HONDA              P         79630
# 23367               P-U        DODGE              P         90980
# 24172              DELV        FRUEH              P         25630
# 32902              DELV        FRUEH              P         68020
# 32903               VAN         FORD              P         68020
#
#        Street Code2  Street Code3  ... From Hours In Effect  \
# 1609          40404         40404  ...                  ALL
# 23367             0             0  ...                  ALL
# 24172         13610         24985  ...                  ALL
# 32902         26760         66120  ...                  ALL
# 32903         26490         26520  ...                  ALL
#
#       To Hours In Effect  Vehicle Year  Feet From Curb  Violation Post Code  \
# 1609                 ALL        2013.0             5.0              Unknown
# 23367                ALL        2002.0             0.0              Unknown
# 24172                ALL        1999.0             0.0              Unknown
# 32902                ALL        2007.0             0.0              Unknown
# 32903                ALL        2011.0             0.0              Unknown
#
#       Violation Description Plate Type Vehicle Color Issue Date  \
# 1609                Unknown        PAS         BROWN 2013-10-23
# 23367               Unknown        PAS           RED 2013-10-21
# 24172               Unknown        COM         WHITE 2013-10-17
# 32902               Unknown        COM         WHITE 2013-10-10
# 32903               Unknown        COM         WHITE 2013-10-10
#
#       Citation Issued Month Year
# 1609                      201310
# 23367                     201310
# 24172                     201310
# 32902                     201310
# 32903                     201310
#
# [5 rows x 36 columns]

# %%
# 2016년 4월 25일 이후의 모든 주차 위반 기록 찾기
bound_date = '2016-4-25'
condition = nyc_data_derived_stage5['Issue Date'] > bound_date
citations_after_bound = nyc_data_derived_stage5[condition]

with ProgressBar() :
    display(citations_after_bound.head())
# Out:
# [########################################] | 100% Completed |  8.6s
#        Summons Number Plate ID Registration State  Violation Code  \
# 3741       1346495701  GCJ8613                 NY              20
# 3748       1346551819  GHJ2373                 NY              20
# 6905       1348077426  66811MB                 NY              78
# 12967      1353305650  91609MC                 NY              46
# 17144      1354617988  54015JV                 NY              78
#
#       Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 3741                SDN        DODGE              X         10210
# 3748               SUBN         FORD              X             0
# 6905                 IR        FRUEH              P         25680
# 12967               VAN         FORD              T         24890
# 17144               VAN         FORD              P         38590
#
#        Street Code2  Street Code3  ... From Hours In Effect  \
# 3741          19210         19250  ...                  ALL
# 3748              0             0  ...                  ALL
# 6905          46320          8120  ...                0900P
# 12967         18670         18690  ...                  ALL
# 17144         50150         52290  ...                0900P
#
#       To Hours In Effect  Vehicle Year  Feet From Curb  Violation Post Code  \
# 3741                 ALL        2010.0             0.0              Unknown
# 3748                 ALL        2010.0             0.0              Unknown
# 6905               0500A        2007.0             0.0              Unknown
# 12967                ALL        2012.0             0.0              Unknown
# 17144              0500A        2007.0             0.0              Unknown
#
#       Violation Description Plate Type Vehicle Color Issue Date  \
# 3741                Unknown        PAS           BLK 2017-08-04
# 3748                Unknown        PAS           BLK 2019-07-22
# 6905                Unknown        COM           WHT 2053-08-02
# 12967               Unknown        COM            BR 2016-08-07
# 17144               Unknown        COM         WHITE 2032-07-28
#
#       Citation Issued Month Year
# 3741                      201708
# 3748                      201907
# 6905                      205308
# 12967                     201608
# 17144                     203207
#
# [5 rows x 36 columns]

# %%
# 데이터 프레임에서 인덱스 설정하기
with ProgressBar() :
    condition = (nyc_data_derived_stage5['Issue Date'] > '2014-01-01') & \
                (nyc_data_derived_stage5['Issue Date'] < '2017-12-31')
    # 데이터를 필터링하여 2014-01-01과 2017-12-31 사이에 발행된 티켓만 유지
    nyc_data_filtered = nyc_data_derived_stage5[condition]
    nyc_data_new_index = nyc_data_filtered.set_index('Citation Issued Month Year')
    # 데이터 프레임의 인덱스를 월/년 열로 설정
# Out:
# [########################################] | 100% Completed |  1hr  6min 11.4s
# /Users/cbm/workspace/dask/venv/lib/python3.9/site-packages/numpy/core/numeric.py:2446: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return bool(asarray(a1 == a2).all())
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [49], in <cell line: 2>()
#       5 # 데이터를 필터링하여 2014-01-01과 2017-12-31 사이에 발행된 티켓만 유지
#       6 nyc_data_filtered = nyc_data_derived_stage5[condition]
# ----> 7 nyc_data_new_index = nyc_data_filtered.set_index('Citation Issued Month Year')
#
# File ~/workspace/dask/venv/lib/python3.9/site-packages/dask/dataframe/core.py:4681, in DataFrame.set_index(***failed resolving arguments***)
#    4678 else:
#    4679     from dask.dataframe.shuffle import set_index
# -> 4681     return set_index(
#    4682         self,
#    4683         other,
#    4684         drop=drop,
#    4685         npartitions=npartitions,
#    4686         divisions=divisions,
#    4687         **kwargs,
#    4688     )
#
# File ~/workspace/dask/venv/lib/python3.9/site-packages/dask/dataframe/shuffle.py:230, in set_index(df, index, npartitions, shuffle, compute, drop, upsample, divisions, partition_size, **kwargs)
#     227         result = set_sorted_index(df, index, drop=drop, divisions=divisions)
#     228         return result.map_partitions(M.sort_index)
# --> 230 return set_partition(
#     231     df, index, divisions, shuffle=shuffle, drop=drop, compute=compute, **kwargs
#     232 )
#
# File ~/workspace/dask/venv/lib/python3.9/site-packages/dask/dataframe/shuffle.py:312, in set_partition(df, index, divisions, max_branch, drop, shuffle, compute)
#     310     divisions = df._meta._constructor_sliced(divisions)
#     311 else:
# --> 312     divisions = df._meta._constructor_sliced(divisions, dtype=dtype)
#     314 if np.isscalar(index):
#     315     partitions = df[index].map_partitions(
#     316         set_partitions_pre, divisions=divisions, meta=meta
#     317     )
#
# File ~/workspace/dask/venv/lib/python3.9/site-packages/pandas/core/series.py:451, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     449         data = data.copy()
#     450 else:
# --> 451     data = sanitize_array(data, index, dtype, copy)
#     453     manager = get_option("mode.data_manager")
#     454     if manager == "block":
#
# File ~/workspace/dask/venv/lib/python3.9/site-packages/pandas/core/construction.py:591, in sanitize_array(data, index, dtype, copy, raise_cast_failure, allow_2d)
#     588     data = list(data)
#     590 if dtype is not None or len(data) == 0:
# --> 591     subarr = _try_cast(data, dtype, copy, raise_cast_failure)
#     592 else:
#     593     subarr = maybe_convert_platform(data)
#
# File ~/workspace/dask/venv/lib/python3.9/site-packages/pandas/core/construction.py:776, in _try_cast(arr, dtype, copy, raise_cast_failure)
#     770 try:
#     771     # GH#15832: Check if we are requesting a numeric dtype and
#     772     # that we can convert the data to the requested dtype.
#     773     if is_integer_dtype(dtype):
#     774         # this will raise if we have e.g. floats
# --> 776         subarr = maybe_cast_to_integer_array(arr, dtype)
#     777     else:
#     778         # 4 tests fail if we move this to a try/except/else; see
#     779         #  test_constructor_compound_dtypes, test_constructor_cast_failure
#     780         #  test_constructor_dict_cast2, test_loc_setitem_dtype
#     781         subarr = np.array(arr, dtype=dtype, copy=copy)
#
# File ~/workspace/dask/venv/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:2085, in maybe_cast_to_integer_array(arr, dtype, copy)
#    2082     return casted
#    2084 # No known cases that get here, but raising explicitly to cover our bases.
# -> 2085 raise ValueError(f"values cannot be losslessly cast to {dtype}")
#
# ValueError: values cannot be losslessly cast to int64

# %%
# 월/연도별 데이터 재분할
years = ['2014', '2015', '2016', '2017']
months = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']
divisions = [year + month for year in years for month in months]

with ProgressBar() :
    nyc_data_new_index.repartition(divisions=divisions) \
    .to_parquet('nyc_data_date_index', compression='snappy')

nyc_data_new_index = dd.read_parquet('nyc_data_date_index')

# %% [markdown]
# #### 5. 데이터 조인하기

# %%
import pandas as pd

nyc_temps = pd.read_csv('./data/nyc-temp-data.csv')
nyc_temps_indexed = nyc_temps.set_index(nyc_temps.monthYear.astype(str))

nyc_datg_with_temps = nyc_data_new_index.join(nyc_temps_indexed, how='inner')

with ProgressBar() : 
    display(nyc_data_with_temps.head(15))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [53], in <cell line: 6>()
#       3 nyc_temps = pd.read_csv('./data/nyc-temp-data.csv')
#       4 nyc_temps_indexed = nyc_temps.set_index(nyc_temps.monthYear.astype(str))
# ----> 6 nyc_datg_with_temps = nyc_data_new_index.join(nyc_temps_indexed, how='inner')
#       8 with ProgressBar() :
#       9     display(nyc_data_with_temps.head(15))
#
# NameError: name 'nyc_data_new_index' is not defined
